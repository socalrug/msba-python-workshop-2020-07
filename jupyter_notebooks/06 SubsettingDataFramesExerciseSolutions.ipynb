# %% [markdown]
# # Subsetting `DataFrames` -- Exercises

# %% [markdown]
# ## Goal
#
# Practice `pandas` subsetting operations

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 0. Import `pandas` and load the penguins data set

# %%
import pandas as pd

penguins = pd.read_csv("https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv")

# %% [markdown]
# ### 1. Get the data from the column for the flipper length.  What is its type of the output when you select a single column from a `DataFrame`?

# %%
# When subsetting to specific columns, it's useful to print out the column names for reference
list(penguins.columns)
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex',
#  'year']

# %%
# Just index the DataFrame with the column name
flipper_len = penguins["flipper_length_mm"]
flipper_len.head(10)
# Out:
# 0    181.0
# 1    186.0
# 2    195.0
# 3      NaN
# 4    193.0
# 5    190.0
# 6    181.0
# 7    195.0
# 8    193.0
# 9    190.0
# Name: flipper_length_mm, dtype: float64

# %%
# Use the type function to get the type of the output
# Here, the type is a pandas Series object since we only selected a single column
type(flipper_len)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 2. Subset the penguins data to just the columns containing length/depth measurements.  What is the type of the output when you select multiple columns from a `DataFrame`?

# %%
# Subsetting to multiple columns requires wraping the column names in a Python list with []
length_data = penguins[["bill_length_mm", "bill_depth_mm", "flipper_length_mm"]]
length_data.head(10)
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm
# 0            39.1           18.7              181.0
# 1            39.5           17.4              186.0
# 2            40.3           18.0              195.0
# 3             NaN            NaN                NaN
# 4            36.7           19.3              193.0
# 5            39.3           20.6              190.0
# 6            38.9           17.8              181.0
# 7            39.2           19.6              195.0
# 8            34.1           18.1              193.0
# 9            42.0           20.2              190.0

# %%
# Since multiple columns were selected, the output is DataFrame
type(length_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 3. What are the names of the different islands represented in the data set?

# %%
# Select the island column, then get the unique values
list(penguins["island"].unique())
# Out:
# ['Torgersen', 'Biscoe', 'Dream']

# %% [markdown]
# ### 4. How many rows have missing body mass values?
#
# Hint: You'll need to find (or guess) the name of a helper function very similar to one we used in the lesson.

# %%
# The isna function indicates whether or not a value is missing
penguins[penguins["body_mass_g"].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 271          NaN  NaN  2009

# %%
# It's easy to count the rows from the output, but if there were many more
# shape can be used to get the count programatically
penguins[penguins["body_mass_g"].isna()].shape[0]
# Out:
# 2

# %% [markdown]
# ### 5. Get the subset of data that match ALL of the following criteria
#
# * Penguins of the Gentoo and Chinstrap species
# * Flipper length less than 200
# * Females only

# %%
# This is mainly an exercise in getting the syntax correct
penguins[(penguins["species"].isin(["Gentoo", "Chinstrap"])) & \
         (penguins["flipper_length_mm"] < 200) & \
         (penguins["sex"] == "female")]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 281  Chinstrap  Dream            45.2           17.8              198.0
# 282  Chinstrap  Dream            46.1           18.2              178.0
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 286  Chinstrap  Dream            46.6           17.8              193.0
# 288  Chinstrap  Dream            47.0           17.3              185.0
# 290  Chinstrap  Dream            45.9           17.1              190.0
# 293  Chinstrap  Dream            58.0           17.8              181.0
# 294  Chinstrap  Dream            46.4           18.6              190.0
# 296  Chinstrap  Dream            42.4           17.3              181.0
# 298  Chinstrap  Dream            43.2           16.6              187.0
# 300  Chinstrap  Dream            46.7           17.9              195.0
# 304  Chinstrap  Dream            46.4           17.8              191.0
# 306  Chinstrap  Dream            40.9           16.6              187.0
# 308  Chinstrap  Dream            42.5           16.7              187.0
# 311  Chinstrap  Dream            47.5           16.8              199.0
# 312  Chinstrap  Dream            47.6           18.3              195.0
# 314  Chinstrap  Dream            46.9           16.6              192.0
# 317  Chinstrap  Dream            46.2           17.5              187.0
# 319  Chinstrap  Dream            45.5           17.0              196.0
# 320  Chinstrap  Dream            50.9           17.9              196.0
# 322  Chinstrap  Dream            50.1           17.9              190.0
# 325  Chinstrap  Dream            49.8           17.3              198.0
# 326  Chinstrap  Dream            48.1           16.4              199.0
# 328  Chinstrap  Dream            45.7           17.3              193.0
# 330  Chinstrap  Dream            42.5           17.3              187.0
# 332  Chinstrap  Dream            45.2           16.6              191.0
# 335  Chinstrap  Dream            45.6           19.4              194.0
# 337  Chinstrap  Dream            46.8           16.5              189.0
# 338  Chinstrap  Dream            45.7           17.0              195.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 279       3525.0  female  2007
# 281       3950.0  female  2007
# 282       3250.0  female  2007
# 284       4150.0  female  2007
# 286       3800.0  female  2007
# 288       3700.0  female  2007
# 290       3575.0  female  2007
# 293       3700.0  female  2007
# 294       3450.0  female  2007
# 296       3600.0  female  2007
# 298       2900.0  female  2007
# 300       3300.0  female  2007
# 304       3700.0  female  2008
# 306       3200.0  female  2008
# 308       3350.0  female  2008
# 311       3900.0  female  2008
# 312       3850.0  female  2008
# 314       2700.0  female  2008
# 317       3650.0  female  2008
# 319       3500.0  female  2008
# 320       3675.0  female  2009
# 322       3400.0  female  2009
# 325       3675.0  female  2009
# 326       3325.0  female  2009
# 328       3600.0  female  2009
# 330       3350.0  female  2009
# 332       3250.0  female  2009
# 335       3525.0  female  2009
# 337       3650.0  female  2009
# 338       3650.0  female  2009
# 343       3775.0  female  2009

# %% [markdown]
# ### 6. If we only wanted to select the `species`, `flipper_length_mm`, and `sex` columns from the above exercise, how would we need to modify the code?

# %%
# To filter rows AND select specific columns, we need to use the .loc function
penguins.loc[(penguins["species"].isin(["Gentoo", "Chinstrap"])) & \
             (penguins["flipper_length_mm"] < 200) & \
             (penguins["sex"] == "female"), ["species", "flipper_length_mm", "sex"]]
# Out:
#        species  flipper_length_mm     sex
# 276  Chinstrap              192.0  female
# 279  Chinstrap              188.0  female
# 281  Chinstrap              198.0  female
# 282  Chinstrap              178.0  female
# 284  Chinstrap              195.0  female
# 286  Chinstrap              193.0  female
# 288  Chinstrap              185.0  female
# 290  Chinstrap              190.0  female
# 293  Chinstrap              181.0  female
# 294  Chinstrap              190.0  female
# 296  Chinstrap              181.0  female
# 298  Chinstrap              187.0  female
# 300  Chinstrap              195.0  female
# 304  Chinstrap              191.0  female
# 306  Chinstrap              187.0  female
# 308  Chinstrap              187.0  female
# 311  Chinstrap              199.0  female
# 312  Chinstrap              195.0  female
# 314  Chinstrap              192.0  female
# 317  Chinstrap              187.0  female
# 319  Chinstrap              196.0  female
# 320  Chinstrap              196.0  female
# 322  Chinstrap              190.0  female
# 325  Chinstrap              198.0  female
# 326  Chinstrap              199.0  female
# 328  Chinstrap              193.0  female
# 330  Chinstrap              187.0  female
# 332  Chinstrap              191.0  female
# 335  Chinstrap              194.0  female
# 337  Chinstrap              189.0  female
# 338  Chinstrap              195.0  female
# 343  Chinstrap              198.0  female
